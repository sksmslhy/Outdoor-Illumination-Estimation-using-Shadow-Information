# %% [markdown]
# ## 3 Channel, Alex, Only Sun

# %%
# Math
import numpy as np
# Pytorch
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch import optim
from torch.optim.lr_scheduler import StepLR
# Custom
from loader import  AlexNetModule_SUN, Train_Dataset_SUN, Eval_Dataset_SUN
import os
from libs.projections import bin2Sphere
from utils import getAngle

os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# For updating learning rate
def update_lr(optimizer, lr):    
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
BATCH_SIZE = 64
EPOCHS = 500

# 하이퍼파라미터 설정
learning_rate = 0.01

# %%
dataset = Train_Dataset_SUN(csv_path='./mydata/trans_mode_label.csv')
train_dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=8)

# %%
eval_dataset = Eval_Dataset_SUN(csv_path='./mydata/trans_mode_label.csv')
eval_dataloader = DataLoader(eval_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %%
illuminationModule = AlexNetModule_SUN().cuda()

# %%
from torchsummary import summary

summary(illuminationModule, input_size=(3,320,240))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 79, 59]          23,296
#                ELU-2           [-1, 64, 79, 59]               0
#          MaxPool2d-3           [-1, 64, 39, 29]               0
#             Conv2d-4          [-1, 192, 39, 29]         307,392
#                ELU-5          [-1, 192, 39, 29]               0
#          MaxPool2d-6          [-1, 192, 19, 14]               0
#             Conv2d-7          [-1, 384, 19, 14]         663,936
#                ELU-8          [-1, 384, 19, 14]               0
#             Conv2d-9          [-1, 256, 19, 14]         884,992
#               ELU-10          [-1, 256, 19, 14]               0
#            Conv2d-11          [-1, 256, 19, 14]         590,080
#               ELU-12          [-1, 256, 19, 14]               0
#         MaxPool2d-13            [-1, 256, 9, 6]               0
#           Dropout-14                [-1, 13824]               0
#            Linear-15                 [-1, 4096]      56,627,200
#               ELU-16                 [-1, 4096]               0
#           Dropout-17                 [-1, 4096]               0
#            Linear-18                 [-1, 4096]      16,781,312
#               ELU-19                 [-1, 4096]               0
#            Linear-20                 [-1, 2048]       8,390,656
#       BatchNorm1d-21                 [-1, 2048]           4,096
#            Linear-22                  [-1, 256]         524,544
#       BatchNorm1d-23                  [-1, 256]             512
# ================================================================
# Total params: 84,798,016
# Trainable params: 84,798,016
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.88
# Forward/backward pass size (MB): 12.85
# Params size (MB): 323.48
# Estimated Total Size (MB): 337.20
# ----------------------------------------------------------------

# %%
sun_crit = nn.KLDivLoss()
prr_crit = nn.MSELoss()
# set optimizer
optimizer = optim.Adam(illuminationModule.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.LambdaLR(optimizer=optimizer,
                                lr_lambda=lambda epoch: 0.95 ** epoch,
                                last_epoch=-1,)

# %%
def trainloop(module, lr=0.01, train_epochs=EPOCHS):
    global total_l, sky_l, sun_l
    # set training dataset
    dataset = Train_Dataset_SUN(csv_path='./mydata/trans_mode_label.csv')
    train_dataloader = DataLoader(dataset, batch_size=64, shuffle=True, num_workers=8)

    # using KL divergence loss for sun distribution and MSE loss  
    sun_crit = nn.KLDivLoss()
    # set optimizer
    optimizer = torch.optim.Adam(module.parameters(), lr=lr)

    # train the model
    cur_lr = lr

    for i in range(train_epochs):
        for i_batch, sample in enumerate(train_dataloader):
            # training input and targets
            img = sample['img'].cuda().float()
            label_dis = sample['dis'].cuda().float()

            # forward pass 
            pred_dis = module(img)
            beta = 0.1 # to compensate for the number od bins in output distribution
            loss = sun_crit(pred_dis, label_dis)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        total_l.append(loss.item())
        
        print('='*20,'EPOCH : ', i,'='*20)
        print('-'*20,'TRAIN','-'*20)
        print("sun_loss : {:.5f} ".format(loss.item()))
        print('-'*20,'TEST','-'*20)
        evaluate(module, eval_dataloader, optimizer, train_epochs)
        
        # Decay learning rate (0.5/15 epochs)
        if i % 15 == 0:
            cur_lr *= 0.5
            update_lr(optimizer, cur_lr)
        

    # Save the model checkpoint
    torch.save(module.state_dict(), '17_sun_alex_weights.pth')

# %%
test_total_l = []

def evaluate(module, eval_dataloader, optimizer, epoch):
    # loss function
    sun_crit = nn.KLDivLoss()
    prr_crit = nn.MSELoss()

    # data loader
    eval_dataset = Eval_Dataset_SUN(csv_path='./mydata/trans_mode_label.csv')
    eval_dataloader = DataLoader(eval_dataset, batch_size=1, shuffle=False, num_workers=4)

    module.eval()
    
    sum_err = np.asarray([0, 0]).astype('float64')
    sum_loss = 0.0
    data_length = len(eval_dataloader)
    suns=[]
    suns_gt=[]
    bins=[]
    angular=[]
    for i, sample in enumerate(eval_dataloader):
        input_img = sample['img'].cuda().float()
        label_dis = sample['dis'].cuda().float()
        sunpos = sample['sp'][0].numpy()

        with torch.no_grad():
            #print("="*20,i,"="*20)
            pred_dis = module(input_img)
            loss = sun_crit(pred_dis, label_dis)

            # calculate all prediction error
            bins.append(np.argmax(pred_dis.cpu().numpy()[0]))
            pred_sunpos = bin2Sphere(np.argmax(pred_dis.cpu().numpy()[0])) # predicted sun position is the bin with highest probability
            #print('pred_sunpos : ', pred_sunpos)
            suns.append(pred_sunpos)
            suns_gt.append(sunpos)
            sunpos_err = getAngle(sunpos, pred_sunpos)
            angular.append(sunpos_err)
            sum_err += np.asarray([sunpos_err])
    print("sun_loss : {:.5f}".format(loss.item()))
    test_total_l.append(loss.item())
    # print average prediction errors across all testing dataset
    if epoch == 499:    
        print("="*20,"FINAL ERROR","="*20)
        print('Testing avg loss:', sum_loss/data_length)
        final_err = sum_err/data_length
        print('Average predictions error:')
        print('sun position (angular error):', final_err[0])
    return suns_gt, suns, bins, angular

# %%
def main():

    # device configuration
    torch.cuda.set_device(0)
    # get network module 
    Module = AlexNetModule_SUN().cuda()

    trainloop(Module)
    
total_l = []
sun_l = []
sky_l = []

if __name__ == '__main__':
    main()
# Out:
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1932: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn("reduction: 'mean' divides the total loss by both the batch size and the support size."
# ==================== EPOCH :  0 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01321
# -------------------- TEST --------------------
# sun_loss : 0.06633
# ==================== EPOCH :  1 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01230
# -------------------- TEST --------------------
# sun_loss : 0.01033
# ==================== EPOCH :  2 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01229
# -------------------- TEST --------------------
# sun_loss : 0.00925
# ==================== EPOCH :  3 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01154
# -------------------- TEST --------------------
# sun_loss : 0.00956
# ==================== EPOCH :  4 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01202
# -------------------- TEST --------------------
# sun_loss : 0.01101
# ==================== EPOCH :  5 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01163
# -------------------- TEST --------------------
# sun_loss : 0.01186
# ==================== EPOCH :  6 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01156
# -------------------- TEST --------------------
# sun_loss : 0.00966
# ==================== EPOCH :  7 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01239
# -------------------- TEST --------------------
# sun_loss : 0.01118
# ==================== EPOCH :  8 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01177
# -------------------- TEST --------------------
# sun_loss : 0.01022
# ==================== EPOCH :  9 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01165
# -------------------- TEST --------------------
# sun_loss : 0.00854
# ==================== EPOCH :  10 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01117
# -------------------- TEST --------------------
# sun_loss : 0.00867
# ==================== EPOCH :  11 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01125
# -------------------- TEST --------------------
# sun_loss : 0.01064
# ==================== EPOCH :  12 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01051
# -------------------- TEST --------------------
# sun_loss : 0.00983
# ==================== EPOCH :  13 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01117
# -------------------- TEST --------------------
# sun_loss : 0.00944
# ==================== EPOCH :  14 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01089
# -------------------- TEST --------------------
# sun_loss : 0.00894
# ==================== EPOCH :  15 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01094
# -------------------- TEST --------------------
# sun_loss : 0.00949
# ==================== EPOCH :  16 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01097
# -------------------- TEST --------------------
# sun_loss : 0.00948
# ==================== EPOCH :  17 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01107
# -------------------- TEST --------------------
# sun_loss : 0.00972
# ==================== EPOCH :  18 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01030
# -------------------- TEST --------------------
# sun_loss : 0.00917
# ==================== EPOCH :  19 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01092
# -------------------- TEST --------------------
# sun_loss : 0.00927
# ==================== EPOCH :  20 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01106
# -------------------- TEST --------------------
# sun_loss : 0.00909
# ==================== EPOCH :  21 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01082
# -------------------- TEST --------------------
# sun_loss : 0.00926
# ==================== EPOCH :  22 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01084
# -------------------- TEST --------------------
# sun_loss : 0.00960
# ==================== EPOCH :  23 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01047
# -------------------- TEST --------------------
# sun_loss : 0.00995
# ==================== EPOCH :  24 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01109
# -------------------- TEST --------------------
# sun_loss : 0.00939
# ==================== EPOCH :  25 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01007
# -------------------- TEST --------------------
# sun_loss : 0.00902
# ==================== EPOCH :  26 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01051
# -------------------- TEST --------------------
# sun_loss : 0.00912
# ==================== EPOCH :  27 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01018
# -------------------- TEST --------------------
# sun_loss : 0.00959
# ==================== EPOCH :  28 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01085
# -------------------- TEST --------------------
# sun_loss : 0.00879
# ==================== EPOCH :  29 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01080
# -------------------- TEST --------------------
# sun_loss : 0.00886
# ==================== EPOCH :  30 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01030
# -------------------- TEST --------------------
# sun_loss : 0.00950
# ==================== EPOCH :  31 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00989
# -------------------- TEST --------------------
# sun_loss : 0.00979
# ==================== EPOCH :  32 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01010
# -------------------- TEST --------------------
# sun_loss : 0.00990
# ==================== EPOCH :  33 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00993
# -------------------- TEST --------------------
# sun_loss : 0.00919
# ==================== EPOCH :  34 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00991
# -------------------- TEST --------------------
# sun_loss : 0.00893
# ==================== EPOCH :  35 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00945
# -------------------- TEST --------------------
# sun_loss : 0.01127
# ==================== EPOCH :  36 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01036
# -------------------- TEST --------------------
# sun_loss : 0.00885
# ==================== EPOCH :  37 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01031
# -------------------- TEST --------------------
# sun_loss : 0.00875
# ==================== EPOCH :  38 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00965
# -------------------- TEST --------------------
# sun_loss : 0.00913
# ==================== EPOCH :  39 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00881
# -------------------- TEST --------------------
# sun_loss : 0.00906
# ==================== EPOCH :  40 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00997
# -------------------- TEST --------------------
# sun_loss : 0.00918
# ==================== EPOCH :  41 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00854
# -------------------- TEST --------------------
# sun_loss : 0.00957
# ==================== EPOCH :  42 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00870
# -------------------- TEST --------------------
# sun_loss : 0.00889
# ==================== EPOCH :  43 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00900
# -------------------- TEST --------------------
# sun_loss : 0.00976
# ==================== EPOCH :  44 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00956
# -------------------- TEST --------------------
# sun_loss : 0.00906
# ==================== EPOCH :  45 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00996
# -------------------- TEST --------------------
# sun_loss : 0.00881
# ==================== EPOCH :  46 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00911
# -------------------- TEST --------------------
# sun_loss : 0.00899
# ==================== EPOCH :  47 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00925
# -------------------- TEST --------------------
# sun_loss : 0.00868
# ==================== EPOCH :  48 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00864
# -------------------- TEST --------------------
# sun_loss : 0.00948
# ==================== EPOCH :  49 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00896
# -------------------- TEST --------------------
# sun_loss : 0.00962
# ==================== EPOCH :  50 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00821
# -------------------- TEST --------------------
# sun_loss : 0.00913
# ==================== EPOCH :  51 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00884
# -------------------- TEST --------------------
# sun_loss : 0.00928
# ==================== EPOCH :  52 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00930
# -------------------- TEST --------------------
# sun_loss : 0.00900
# ==================== EPOCH :  53 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00844
# -------------------- TEST --------------------
# sun_loss : 0.00939
# ==================== EPOCH :  54 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00798
# -------------------- TEST --------------------
# sun_loss : 0.00955
# ==================== EPOCH :  55 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00833
# -------------------- TEST --------------------
# sun_loss : 0.01035
# ==================== EPOCH :  56 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00955
# -------------------- TEST --------------------
# sun_loss : 0.00987
# ==================== EPOCH :  57 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00835
# -------------------- TEST --------------------
# sun_loss : 0.00961
# ==================== EPOCH :  58 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00796
# -------------------- TEST --------------------
# sun_loss : 0.00949
# ==================== EPOCH :  59 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00877
# -------------------- TEST --------------------
# sun_loss : 0.00959
# ==================== EPOCH :  60 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00956
# -------------------- TEST --------------------
# sun_loss : 0.00993
# ==================== EPOCH :  61 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00831
# -------------------- TEST --------------------
# sun_loss : 0.00971
# ==================== EPOCH :  62 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00895
# -------------------- TEST --------------------
# sun_loss : 0.00920
# ==================== EPOCH :  63 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00841
# -------------------- TEST --------------------
# sun_loss : 0.01002
# ==================== EPOCH :  64 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00931
# -------------------- TEST --------------------
# sun_loss : 0.00913
# ==================== EPOCH :  65 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00808
# -------------------- TEST --------------------
# sun_loss : 0.00964
# ==================== EPOCH :  66 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00801
# -------------------- TEST --------------------
# sun_loss : 0.00998
# ==================== EPOCH :  67 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00716
# -------------------- TEST --------------------
# sun_loss : 0.00987
# ==================== EPOCH :  68 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00746
# -------------------- TEST --------------------
# sun_loss : 0.00934
# ==================== EPOCH :  69 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00851
# -------------------- TEST --------------------
# sun_loss : 0.00991
# ==================== EPOCH :  70 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00783
# -------------------- TEST --------------------
# sun_loss : 0.00946
# ==================== EPOCH :  71 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00863
# -------------------- TEST --------------------
# sun_loss : 0.01024
# ==================== EPOCH :  72 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00799
# -------------------- TEST --------------------
# sun_loss : 0.00975
# ==================== EPOCH :  73 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00748
# -------------------- TEST --------------------
# sun_loss : 0.00952
# ==================== EPOCH :  74 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00739
# -------------------- TEST --------------------
# sun_loss : 0.00921
# ==================== EPOCH :  75 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00768
# -------------------- TEST --------------------
# sun_loss : 0.00997
# ==================== EPOCH :  76 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00718
# -------------------- TEST --------------------
# sun_loss : 0.01007
# ==================== EPOCH :  77 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00811
# -------------------- TEST --------------------
# sun_loss : 0.00970
# ==================== EPOCH :  78 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00848
# -------------------- TEST --------------------
# sun_loss : 0.00973
# ==================== EPOCH :  79 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00681
# -------------------- TEST --------------------
# sun_loss : 0.00995
# ==================== EPOCH :  80 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00827
# -------------------- TEST --------------------
# sun_loss : 0.00964
# ==================== EPOCH :  81 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00744
# -------------------- TEST --------------------
# sun_loss : 0.00980
# ==================== EPOCH :  82 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00818
# -------------------- TEST --------------------
# sun_loss : 0.01003
# ==================== EPOCH :  83 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00894
# -------------------- TEST --------------------
# sun_loss : 0.01002
# ==================== EPOCH :  84 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00642
# -------------------- TEST --------------------
# sun_loss : 0.00990
# ==================== EPOCH :  85 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00811
# -------------------- TEST --------------------
# sun_loss : 0.00996
# ==================== EPOCH :  86 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00703
# -------------------- TEST --------------------
# sun_loss : 0.00999
# ==================== EPOCH :  87 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00624
# -------------------- TEST --------------------
# sun_loss : 0.01004
# ==================== EPOCH :  88 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00814
# -------------------- TEST --------------------
# sun_loss : 0.00978
# ==================== EPOCH :  89 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00643
# -------------------- TEST --------------------
# sun_loss : 0.00987
# ==================== EPOCH :  90 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00668
# -------------------- TEST --------------------
# sun_loss : 0.01010
# ==================== EPOCH :  91 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00749
# -------------------- TEST --------------------
# sun_loss : 0.01010
# ==================== EPOCH :  92 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00685
# -------------------- TEST --------------------
# sun_loss : 0.01021
# ==================== EPOCH :  93 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00656
# -------------------- TEST --------------------
# sun_loss : 0.01025
# ==================== EPOCH :  94 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00689
# -------------------- TEST --------------------
# sun_loss : 0.01020
# ==================== EPOCH :  95 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00784
# -------------------- TEST --------------------
# sun_loss : 0.01006
# ==================== EPOCH :  96 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00634
# -------------------- TEST --------------------
# sun_loss : 0.01028
# ==================== EPOCH :  97 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00722
# -------------------- TEST --------------------
# sun_loss : 0.01021
# ==================== EPOCH :  98 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00688
# -------------------- TEST --------------------
# sun_loss : 0.01020
# ==================== EPOCH :  99 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00719
# -------------------- TEST --------------------
# sun_loss : 0.01026
# ==================== EPOCH :  100 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00723
# -------------------- TEST --------------------
# sun_loss : 0.01001
# ==================== EPOCH :  101 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00779
# -------------------- TEST --------------------
# sun_loss : 0.01013
# ==================== EPOCH :  102 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00805
# -------------------- TEST --------------------
# sun_loss : 0.01027
# ==================== EPOCH :  103 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00632
# -------------------- TEST --------------------
# sun_loss : 0.01041
# ==================== EPOCH :  104 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00811
# -------------------- TEST --------------------
# sun_loss : 0.01030
# ==================== EPOCH :  105 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00772
# -------------------- TEST --------------------
# sun_loss : 0.01013
# ==================== EPOCH :  106 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00690
# -------------------- TEST --------------------
# sun_loss : 0.01013
# ==================== EPOCH :  107 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00605
# -------------------- TEST --------------------
# sun_loss : 0.01026
# ==================== EPOCH :  108 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00770
# -------------------- TEST --------------------
# sun_loss : 0.01026
# ==================== EPOCH :  109 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00627
# -------------------- TEST --------------------
# sun_loss : 0.01038
# ==================== EPOCH :  110 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00664
# -------------------- TEST --------------------
# sun_loss : 0.01020
# ==================== EPOCH :  111 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00613
# -------------------- TEST --------------------
# sun_loss : 0.01038
# ==================== EPOCH :  112 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00668
# -------------------- TEST --------------------
# sun_loss : 0.01027
# ==================== EPOCH :  113 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00771
# -------------------- TEST --------------------
# sun_loss : 0.01045
# ==================== EPOCH :  114 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00637
# -------------------- TEST --------------------
# sun_loss : 0.01027
# ==================== EPOCH :  115 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00697
# -------------------- TEST --------------------
# sun_loss : 0.01032
# ==================== EPOCH :  116 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00741
# -------------------- TEST --------------------
# sun_loss : 0.01053
# ==================== EPOCH :  117 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00721
# -------------------- TEST --------------------
# sun_loss : 0.01053
# ==================== EPOCH :  118 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00707
# -------------------- TEST --------------------
# sun_loss : 0.01032
# ==================== EPOCH :  119 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00664
# -------------------- TEST --------------------
# sun_loss : 0.01045
# ==================== EPOCH :  120 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00735
# -------------------- TEST --------------------
# sun_loss : 0.01051
# ==================== EPOCH :  121 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00684
# -------------------- TEST --------------------
# sun_loss : 0.01047
# ==================== EPOCH :  122 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00716
# -------------------- TEST --------------------
# sun_loss : 0.01056
# ==================== EPOCH :  123 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00578
# -------------------- TEST --------------------
# sun_loss : 0.01054
# ==================== EPOCH :  124 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00649
# -------------------- TEST --------------------
# sun_loss : 0.01053
# ==================== EPOCH :  125 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00749
# -------------------- TEST --------------------
# sun_loss : 0.01055
# ==================== EPOCH :  126 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00588
# -------------------- TEST --------------------
# sun_loss : 0.01056
# ==================== EPOCH :  127 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00751
# -------------------- TEST --------------------
# sun_loss : 0.01057
# ==================== EPOCH :  128 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00835
# -------------------- TEST --------------------
# sun_loss : 0.01058
# ==================== EPOCH :  129 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00666
# -------------------- TEST --------------------
# sun_loss : 0.01053
# ==================== EPOCH :  130 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00661
# -------------------- TEST --------------------
# sun_loss : 0.01058
# ==================== EPOCH :  131 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00773
# -------------------- TEST --------------------
# sun_loss : 0.01055
# ==================== EPOCH :  132 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00661
# -------------------- TEST --------------------
# sun_loss : 0.01058
# ==================== EPOCH :  133 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00652
# -------------------- TEST --------------------
# sun_loss : 0.01061
# ==================== EPOCH :  134 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00691
# -------------------- TEST --------------------
# sun_loss : 0.01052
# ==================== EPOCH :  135 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00661
# -------------------- TEST --------------------
# sun_loss : 0.01055
# ==================== EPOCH :  136 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00644
# -------------------- TEST --------------------
# sun_loss : 0.01059
# ==================== EPOCH :  137 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00617
# -------------------- TEST --------------------
# sun_loss : 0.01062
# ==================== EPOCH :  138 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00737
# -------------------- TEST --------------------
# sun_loss : 0.01059
# ==================== EPOCH :  139 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00750
# -------------------- TEST --------------------
# sun_loss : 0.01057
# ==================== EPOCH :  140 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00630
# -------------------- TEST --------------------
# sun_loss : 0.01063
# ==================== EPOCH :  141 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00767
# -------------------- TEST --------------------
# sun_loss : 0.01061
# ==================== EPOCH :  142 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00601
# -------------------- TEST --------------------
# sun_loss : 0.01060
# ==================== EPOCH :  143 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00638
# -------------------- TEST --------------------
# sun_loss : 0.01063
# ==================== EPOCH :  144 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00642
# -------------------- TEST --------------------
# sun_loss : 0.01064
# ==================== EPOCH :  145 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00696
# -------------------- TEST --------------------
# sun_loss : 0.01064
# ==================== EPOCH :  146 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00664
# -------------------- TEST --------------------
# sun_loss : 0.01058
# ==================== EPOCH :  147 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00629
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  148 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00569
# -------------------- TEST --------------------
# sun_loss : 0.01060
# ==================== EPOCH :  149 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00716
# -------------------- TEST --------------------
# sun_loss : 0.01064
# ==================== EPOCH :  150 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00699
# -------------------- TEST --------------------
# sun_loss : 0.01063
# ==================== EPOCH :  151 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00605
# -------------------- TEST --------------------
# sun_loss : 0.01063
# ==================== EPOCH :  152 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00643
# -------------------- TEST --------------------
# sun_loss : 0.01063
# ==================== EPOCH :  153 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00598
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  154 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00726
# -------------------- TEST --------------------
# sun_loss : 0.01066
# ==================== EPOCH :  155 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00579
# -------------------- TEST --------------------
# sun_loss : 0.01065
# ==================== EPOCH :  156 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00634
# -------------------- TEST --------------------
# sun_loss : 0.01064
# ==================== EPOCH :  157 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00772
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  158 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00621
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  159 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00594
# -------------------- TEST --------------------
# sun_loss : 0.01065
# ==================== EPOCH :  160 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00726
# -------------------- TEST --------------------
# sun_loss : 0.01066
# ==================== EPOCH :  161 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00679
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  162 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00695
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  163 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00703
# -------------------- TEST --------------------
# sun_loss : 0.01065
# ==================== EPOCH :  164 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00835
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  165 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00705
# -------------------- TEST --------------------
# sun_loss : 0.01063
# ==================== EPOCH :  166 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00659
# -------------------- TEST --------------------
# sun_loss : 0.01066
# ==================== EPOCH :  167 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00664
# -------------------- TEST --------------------
# sun_loss : 0.01066
# ==================== EPOCH :  168 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00647
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  169 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00653
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  170 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00844
# -------------------- TEST --------------------
# sun_loss : 0.01066
# ==================== EPOCH :  171 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00585
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  172 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00602
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  173 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00626
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  174 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00734
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  175 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00642
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  176 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00701
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  177 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00675
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  178 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00677
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  179 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00634
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  180 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00775
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  181 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00646
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  182 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00605
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  183 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00704
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  184 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00646
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  185 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00687
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  186 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00711
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  187 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00676
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  188 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00659
# -------------------- TEST --------------------
# sun_loss : 0.01067
# ==================== EPOCH :  189 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00645
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  190 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00709
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  191 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00695
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  192 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00607
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  193 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00697
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  194 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00682
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  195 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00542
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  196 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00663
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  197 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00716
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  198 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00665
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  199 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00691
# -------------------- TEST --------------------
# sun_loss : 0.01068
# ==================== EPOCH :  200 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00740
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  201 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00634
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  202 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00763
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  203 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00642
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  204 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00614
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  205 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00698
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  206 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00611
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  207 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00688
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  208 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00731
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  209 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00653
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  210 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00685
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  211 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00622
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  212 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00635
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  213 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00637
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  214 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00626
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  215 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00607
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  216 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00633
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  217 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00688
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  218 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00603
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  219 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00668
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  220 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00617
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  221 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00701
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  222 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00673
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  223 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00665
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  224 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00730
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  225 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00670
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  226 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00573
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  227 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00747
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  228 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00648
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  229 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00563
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  230 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00608
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  231 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00647
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  232 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00649
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  233 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00572
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  234 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00580
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  235 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00663
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  236 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00575
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  237 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00657
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  238 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00643
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  239 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00697
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  240 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00616
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  241 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00669
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  242 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00563
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  243 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00657
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  244 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00580
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  245 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00570
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  246 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00641
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  247 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00682
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  248 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00668
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  249 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00702
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  250 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00733
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ==================== EPOCH :  251 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00720
# -------------------- TEST --------------------
# sun_loss : 0.01069
# ...
# sun_loss : 0.00546
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  416 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00634
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  417 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00641
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  418 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00677
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  419 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00668
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  420 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00647
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  421 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00740
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  422 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00638
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  423 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00583
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  424 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00608
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  425 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00620
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  426 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00688
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  427 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00759
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  428 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00676
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  429 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00778
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  430 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00626
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  431 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00573
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  432 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00746
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  433 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00621
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  434 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00704
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  435 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00800
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  436 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00767
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  437 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00597
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  438 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00689
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  439 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00725
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :  440 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00597
# -------------------- TEST --------------------
# sun_loss : 0.01070
# ==================== EPOCH :
    bins=[]
    angular=[]
    with progressbar.ProgressBar(max_value=data_length) as bar:
        for i, sample in enumerate(eval_dataloader):
            input_img = sample['img'].cuda().float()
            label_dis = sample['dis'].cuda().float()
            sunpos = sample['sp'][0].numpy()

            with torch.no_grad():
                #print("="*20,i,"="*20)
                pred_dis = module(input_img)
                #print("pred_dis  shape : ", pred_dis.shape) # (1, 256)
                #print("pred_dis : ", pred_dis)
                #print("pred_prrs : ", pred_prrs)
                #print(input_img)
                loss = sun_crit(pred_dis, label_dis)
                sum_loss += loss.item()
                
                # calculate all prediction error
                bins.append(np.argmax(pred_dis.cpu().numpy()[0]))
                pred_sunpos = bin2Sphere(np.argmax(pred_dis.cpu().numpy()[0])) # predicted sun position is the bin with highest probability
                #print('pred_sunpos : ', pred_sunpos)
                suns.append(pred_sunpos)
                suns_gt.append(sunpos)
                sunpos_err = getAngle(sunpos, pred_sunpos)
                angular.append(sunpos_err)
                # Sky sun kappa beta turbidity
                sum_err += np.asarray([sunpos_err])
            bar.update(i)
    # print average prediction errors across all testing dataset
    print("="*20,"FINAL ERROR","="*20)
    print('Testing avg loss:', sum_loss/data_length)
    final_err = sum_err/data_length
    print('Average predictions error:')
    print('sun position (angular error):', final_err[0])
    return suns_gt, suns, bins, angular

# %%
def main(args):
    print('loading weights ...')
    # device configuration
    torch.cuda.set_device(0)
    # get network module 
    module = AlexNetModule_SUN().cuda()
    #load pre-trained weight
    module.load_state_dict(torch.load(args.pre_trained))

    print('start evaluating ...')
    suns_gt, suns, bins, angular= evaluate(module)
    print('evaluation done!')
    return suns_gt, suns, bins, angular

# %%
if __name__ == '__main__':
    parser = argparse.ArgumentParser()
  
    parser.add_argument('--pre_trained', default='./17_sun_alex_weights.pth', help='pre-trained weight path')
    
    args = parser.parse_args(args=[])
    
    suns_gt, suns, bins, angular = main(args)
# Out:
# loading weights ...
# start evaluating ...
# <torch.utils.data.dataloader.DataLoader object at 0x7ff7eb27aeb8>
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1932: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn("reduction: 'mean' divides the total loss by both the batch size and the support size."
# 100% (446 of 446) |######################| Elapsed Time: 0:00:01 Time:  0:00:01
# ==================== FINAL ERROR ====================
# Testing avg loss: 0.01042022249536618
# Average predictions error:
# sun position (angular error): 50.77480771963651
# evaluation done!

# %%
print(angular)
# Out:
# [54.57339967202874, 106.77658413983046, 9.574544566482055, 9.574544566482055, 101.49805004676203, 61.86868589094227, 95.60407567701286, 87.39279188597018, 124.20063066716367, 111.59084444409814, 93.68973814827183, 99.0293475057033, 114.86484858156253, 122.95714144531242, 114.86484858156253, 116.71690766792312, 51.74136018756699, 76.52607411814343, 36.02766649884403, 29.8205040348855, 40.44998127273676, 93.15606890264392, 103.90513258484077, 81.82508636450763, 113.19056405065302, 2.4913614820074996, 25.903894206691543, 25.903894206691543, 51.54972298609221, 7.884930010124826, 2.586796334354984, 7.7223521059876274, 7.7223521059876274, 111.61378469302853, 109.37130940766546, 21.692956938502086, 66.39378354222474, 2.696534144584778, 82.18686092533883, 87.03