# %% [markdown]
# ## 4 Channel, CNN , Only Sun

# %%
# Math
import numpy as np
# Pytorch
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch import optim
from torch.optim.lr_scheduler import StepLR
# Custom
from loader import IlluminationModule_SUN_Shadow, Train_Dataset_SUN_Shadow, Eval_Dataset_SUN_Shadow
import os
from libs.projections import bin2Sphere
from utils import getAngle

os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# For updating learning rate
def update_lr(optimizer, lr):    
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
BATCH_SIZE = 64
EPOCHS = 500

# 하이퍼파라미터 설정
learning_rate = 0.001

# %%
dataset = Train_Dataset_SUN_Shadow(csv_path='./mydata/trans_mode_label.csv')
train_dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=8)

# %%
eval_dataset = Eval_Dataset_SUN_Shadow(csv_path='./mydata/trans_mode_label.csv')
test_loader = eval_dataloader = DataLoader(eval_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %%
illuminationModule = IlluminationModule_SUN_Shadow().cuda()

# %%
sun_crit = nn.KLDivLoss()
prr_crit = nn.MSELoss()
# set optimizer
optimizer = optim.Adam(illuminationModule.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.LambdaLR(optimizer=optimizer,
                                lr_lambda=lambda epoch: 0.95 ** epoch,
                                last_epoch=-1,)

# %%
def trainloop(module, lr=0.01, train_epochs=EPOCHS):
    global total_l, sky_l, sun_l
    # set training dataset
    dataset = Train_Dataset_SUN_Shadow(csv_path='./mydata/trans_mode_label.csv')
    train_dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=8)

    # using KL divergence loss for sun distribution and MSE loss  
    sun_crit = nn.KLDivLoss()
    prr_crit = nn.MSELoss()
    # set optimizer
    optimizer = torch.optim.Adam(module.parameters(), lr=lr)

    # train the model
    cur_lr = lr

    for i in range(train_epochs):
        module.train()
        for i_batch, sample in enumerate(train_dataloader):
            # training input and targets
            img = sample['img'].cuda().float()
            label_dis = sample['dis'].cuda().float()

            # forward pass 
            pred_dis = module(img)
            sun_loss = sun_crit(pred_dis, label_dis)
            loss = sun_loss 

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
        total_l.append(loss.item())
        
        print('='*20,'EPOCH : ', i,'='*20)
        print('-'*20,'TRAIN','-'*20)
        print("sun_loss : {:.5f}".format(sun_loss.item()))
        print('-'*20,'TEST','-'*20)
        evaluate(module, eval_dataloader, optimizer, train_epochs)
        
        # Decay learning rate (0.5/15 epochs)
        if i % 15 == 0:
            cur_lr *= 0.5
            update_lr(optimizer, cur_lr)
        

    # Save the model checkpoint
    torch.save(module.state_dict(), 'shadow_17_sun_weights.pth')

# %%
test_total_l = []

def evaluate(module, eval_dataloader, optimizer, epoch):
    module.eval()
    
    sum_err = np.asarray([0, 0]).astype('float64')
    sum_loss = 0.0
    data_length = len(eval_dataloader)
    suns=[]
    suns_gt=[]
    bins=[]
    angular=[]
    
    for i, sample in enumerate(eval_dataloader):
        num_of_mini_batch = len(eval_dataloader)
        input_img = sample['img'].cuda().float()
        label_dis = sample['dis'].cuda().float()
        sunpos = sample['sp'][0].numpy()

        with torch.no_grad():
            pred_dis = module(input_img)
            sun_loss = sun_crit(pred_dis, label_dis)
            beta = 0.1
            loss = sun_loss
            sum_loss += loss.item()
            # calculate all prediction error
            bins.append(np.argmax(pred_dis.cpu().numpy()[0]))
            pred_sunpos = bin2Sphere(np.argmax(pred_dis.cpu().numpy()[0])) # predicted sun position is the bin with highest probability
            suns.append(pred_sunpos)
            suns_gt.append(sunpos)
            sunpos_err = getAngle(sunpos, pred_sunpos)

            angular.append(sunpos_err)
            # Sky sun kappa beta turbidity
            sum_err += np.asarray([sunpos_err])

            
    print("sun_loss : {:.5f}".format(loss.item()))
                
    test_total_l.append(loss.item())
    if epoch == 499:
        print("="*20,"FINAL ERROR","="*20)
        final_err = sum_err/data_length
        print('sun position (angular error):', final_err[0])
    return suns_gt, suns, bins, angular

# %%
def main():

    # device configuration
    torch.cuda.set_device(0)
    # get network module 
    Module = IlluminationModule_SUN_Shadow().cuda()

    trainloop(Module)
    
total_l = []
sun_l = []
sky_l = []

if __name__ == '__main__':
    main()
# Out:
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1932: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn("reduction: 'mean' divides the total loss by both the batch size and the support size."
# ==================== EPOCH :  0 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01251
# -------------------- TEST --------------------
# sun_loss : 0.07068
# ==================== EPOCH :  1 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01123
# -------------------- TEST --------------------
# sun_loss : 0.01439
# ==================== EPOCH :  2 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01201
# -------------------- TEST --------------------
# sun_loss : 0.01194
# ==================== EPOCH :  3 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01115
# -------------------- TEST --------------------
# sun_loss : 0.01164
# ==================== EPOCH :  4 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01032
# -------------------- TEST --------------------
# sun_loss : 0.01146
# ==================== EPOCH :  5 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01042
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  6 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01010
# -------------------- TEST --------------------
# sun_loss : 0.01124
# ==================== EPOCH :  7 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00958
# -------------------- TEST --------------------
# sun_loss : 0.01115
# ==================== EPOCH :  8 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01018
# -------------------- TEST --------------------
# sun_loss : 0.01181
# ==================== EPOCH :  9 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.01008
# -------------------- TEST --------------------
# sun_loss : 0.01074
# ==================== EPOCH :  10 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00933
# -------------------- TEST --------------------
# sun_loss : 0.01128
# ==================== EPOCH :  11 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00964
# -------------------- TEST --------------------
# sun_loss : 0.01107
# ==================== EPOCH :  12 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00894
# -------------------- TEST --------------------
# sun_loss : 0.01094
# ==================== EPOCH :  13 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00786
# -------------------- TEST --------------------
# sun_loss : 0.01115
# ==================== EPOCH :  14 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00932
# -------------------- TEST --------------------
# sun_loss : 0.01100
# ==================== EPOCH :  15 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00820
# -------------------- TEST --------------------
# sun_loss : 0.01201
# ==================== EPOCH :  16 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00689
# -------------------- TEST --------------------
# sun_loss : 0.01065
# ==================== EPOCH :  17 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00705
# -------------------- TEST --------------------
# sun_loss : 0.01095
# ==================== EPOCH :  18 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00752
# -------------------- TEST --------------------
# sun_loss : 0.01150
# ==================== EPOCH :  19 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00639
# -------------------- TEST --------------------
# sun_loss : 0.01116
# ==================== EPOCH :  20 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00503
# -------------------- TEST --------------------
# sun_loss : 0.01159
# ==================== EPOCH :  21 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00583
# -------------------- TEST --------------------
# sun_loss : 0.01139
# ==================== EPOCH :  22 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00577
# -------------------- TEST --------------------
# sun_loss : 0.01135
# ==================== EPOCH :  23 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00535
# -------------------- TEST --------------------
# sun_loss : 0.01190
# ==================== EPOCH :  24 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00615
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  25 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00456
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  26 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00485
# -------------------- TEST --------------------
# sun_loss : 0.01126
# ==================== EPOCH :  27 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00463
# -------------------- TEST --------------------
# sun_loss : 0.01212
# ==================== EPOCH :  28 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00447
# -------------------- TEST --------------------
# sun_loss : 0.01211
# ==================== EPOCH :  29 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00439
# -------------------- TEST --------------------
# sun_loss : 0.01274
# ==================== EPOCH :  30 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00372
# -------------------- TEST --------------------
# sun_loss : 0.01197
# ==================== EPOCH :  31 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00377
# -------------------- TEST --------------------
# sun_loss : 0.01179
# ==================== EPOCH :  32 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00287
# -------------------- TEST --------------------
# sun_loss : 0.01180
# ==================== EPOCH :  33 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00338
# -------------------- TEST --------------------
# sun_loss : 0.01158
# ==================== EPOCH :  34 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00300
# -------------------- TEST --------------------
# sun_loss : 0.01179
# ==================== EPOCH :  35 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00296
# -------------------- TEST --------------------
# sun_loss : 0.01194
# ==================== EPOCH :  36 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00238
# -------------------- TEST --------------------
# sun_loss : 0.01147
# ==================== EPOCH :  37 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00276
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  38 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00216
# -------------------- TEST --------------------
# sun_loss : 0.01160
# ==================== EPOCH :  39 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00237
# -------------------- TEST --------------------
# sun_loss : 0.01137
# ==================== EPOCH :  40 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00256
# -------------------- TEST --------------------
# sun_loss : 0.01161
# ==================== EPOCH :  41 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00258
# -------------------- TEST --------------------
# sun_loss : 0.01159
# ==================== EPOCH :  42 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00217
# -------------------- TEST --------------------
# sun_loss : 0.01202
# ==================== EPOCH :  43 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00211
# -------------------- TEST --------------------
# sun_loss : 0.01148
# ==================== EPOCH :  44 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00198
# -------------------- TEST --------------------
# sun_loss : 0.01192
# ==================== EPOCH :  45 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00182
# -------------------- TEST --------------------
# sun_loss : 0.01193
# ==================== EPOCH :  46 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00203
# -------------------- TEST --------------------
# sun_loss : 0.01165
# ==================== EPOCH :  47 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00168
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  48 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00196
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  49 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00161
# -------------------- TEST --------------------
# sun_loss : 0.01162
# ==================== EPOCH :  50 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00132
# -------------------- TEST --------------------
# sun_loss : 0.01153
# ==================== EPOCH :  51 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00131
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  52 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00168
# -------------------- TEST --------------------
# sun_loss : 0.01195
# ==================== EPOCH :  53 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00184
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  54 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00140
# -------------------- TEST --------------------
# sun_loss : 0.01198
# ==================== EPOCH :  55 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00146
# -------------------- TEST --------------------
# sun_loss : 0.01182
# ==================== EPOCH :  56 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00187
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  57 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00134
# -------------------- TEST --------------------
# sun_loss : 0.01154
# ==================== EPOCH :  58 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00183
# -------------------- TEST --------------------
# sun_loss : 0.01185
# ==================== EPOCH :  59 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00144
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  60 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00125
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  61 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00141
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  62 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00168
# -------------------- TEST --------------------
# sun_loss : 0.01210
# ==================== EPOCH :  63 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00169
# -------------------- TEST --------------------
# sun_loss : 0.01185
# ==================== EPOCH :  64 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00182
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  65 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00126
# -------------------- TEST --------------------
# sun_loss : 0.01184
# ==================== EPOCH :  66 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00184
# -------------------- TEST --------------------
# sun_loss : 0.01186
# ==================== EPOCH :  67 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00153
# -------------------- TEST --------------------
# sun_loss : 0.01154
# ==================== EPOCH :  68 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00151
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  69 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00186
# -------------------- TEST --------------------
# sun_loss : 0.01188
# ==================== EPOCH :  70 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00129
# -------------------- TEST --------------------
# sun_loss : 0.01186
# ==================== EPOCH :  71 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00168
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  72 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00179
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  73 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00150
# -------------------- TEST --------------------
# sun_loss : 0.01178
# ==================== EPOCH :  74 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00182
# -------------------- TEST --------------------
# sun_loss : 0.01192
# ==================== EPOCH :  75 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00127
# -------------------- TEST --------------------
# sun_loss : 0.01164
# ==================== EPOCH :  76 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00192
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  77 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00123
# -------------------- TEST --------------------
# sun_loss : 0.01178
# ==================== EPOCH :  78 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00171
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  79 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00149
# -------------------- TEST --------------------
# sun_loss : 0.01185
# ==================== EPOCH :  80 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00155
# -------------------- TEST --------------------
# sun_loss : 0.01184
# ==================== EPOCH :  81 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00122
# -------------------- TEST --------------------
# sun_loss : 0.01185
# ==================== EPOCH :  82 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00170
# -------------------- TEST --------------------
# sun_loss : 0.01179
# ==================== EPOCH :  83 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00159
# -------------------- TEST --------------------
# sun_loss : 0.01187
# ==================== EPOCH :  84 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00111
# -------------------- TEST --------------------
# sun_loss : 0.01186
# ==================== EPOCH :  85 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00158
# -------------------- TEST --------------------
# sun_loss : 0.01180
# ==================== EPOCH :  86 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00146
# -------------------- TEST --------------------
# sun_loss : 0.01181
# ==================== EPOCH :  87 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00147
# -------------------- TEST --------------------
# sun_loss : 0.01165
# ==================== EPOCH :  88 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00127
# -------------------- TEST --------------------
# sun_loss : 0.01179
# ==================== EPOCH :  89 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00161
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  90 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00126
# -------------------- TEST --------------------
# sun_loss : 0.01147
# ==================== EPOCH :  91 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00166
# -------------------- TEST --------------------
# sun_loss : 0.01157
# ==================== EPOCH :  92 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00188
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  93 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00144
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  94 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00112
# -------------------- TEST --------------------
# sun_loss : 0.01163
# ==================== EPOCH :  95 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00147
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  96 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00176
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  97 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00105
# -------------------- TEST --------------------
# sun_loss : 0.01162
# ==================== EPOCH :  98 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00144
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  99 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00142
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  100 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00144
# -------------------- TEST --------------------
# sun_loss : 0.01180
# ==================== EPOCH :  101 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00146
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  102 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00146
# -------------------- TEST --------------------
# sun_loss : 0.01178
# ==================== EPOCH :  103 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00135
# -------------------- TEST --------------------
# sun_loss : 0.01159
# ==================== EPOCH :  104 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00139
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  105 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00124
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  106 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00131
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  107 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00126
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  108 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00140
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  109 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00155
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  110 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00158
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  111 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00144
# -------------------- TEST --------------------
# sun_loss : 0.01180
# ==================== EPOCH :  112 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00132
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  113 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00121
# -------------------- TEST --------------------
# sun_loss : 0.01179
# ==================== EPOCH :  114 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00103
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  115 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00132
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  116 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00116
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  117 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00116
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  118 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00121
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  119 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00180
# -------------------- TEST --------------------
# sun_loss : 0.01163
# ==================== EPOCH :  120 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00155
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  121 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00124
# -------------------- TEST --------------------
# sun_loss : 0.01163
# ==================== EPOCH :  122 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00144
# -------------------- TEST --------------------
# sun_loss : 0.01161
# ==================== EPOCH :  123 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00171
# -------------------- TEST --------------------
# sun_loss : 0.01163
# ==================== EPOCH :  124 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00145
# -------------------- TEST --------------------
# sun_loss : 0.01163
# ==================== EPOCH :  125 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00153
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  126 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00200
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  127 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00135
# -------------------- TEST --------------------
# sun_loss : 0.01165
# ==================== EPOCH :  128 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00163
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  129 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00108
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  130 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00106
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  131 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00128
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  132 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00118
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  133 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00147
# -------------------- TEST --------------------
# sun_loss : 0.01163
# ==================== EPOCH :  134 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00111
# -------------------- TEST --------------------
# sun_loss : 0.01165
# ==================== EPOCH :  135 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00241
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  136 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00107
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  137 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00185
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  138 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00154
# -------------------- TEST --------------------
# sun_loss : 0.01165
# ==================== EPOCH :  139 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00172
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  140 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00163
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  141 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00144
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  142 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00148
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  143 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00133
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  144 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00145
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  145 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00191
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  146 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00167
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  147 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00189
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  148 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00126
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  149 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00150
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  150 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00114
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  151 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00185
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  152 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00151
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  153 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00124
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  154 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00119
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  155 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00158
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  156 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00109
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  157 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00140
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  158 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00225
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  159 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00113
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  160 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00174
# -------------------- TEST --------------------
# sun_loss : 0.01178
# ==================== EPOCH :  161 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00124
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  162 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00114
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  163 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00142
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  164 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00140
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  165 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00149
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  166 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00155
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  167 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00143
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  168 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00151
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  169 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00156
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  170 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00179
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  171 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00186
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  172 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00129
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  173 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00138
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  174 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00150
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  175 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00163
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  176 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00171
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  177 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00151
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  178 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00197
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  179 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00141
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  180 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00137
# -------------------- TEST --------------------
# sun_loss : 0.01163
# ==================== EPOCH :  181 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00139
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  182 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00122
# -------------------- TEST --------------------
# sun_loss : 0.01165
# ==================== EPOCH :  183 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00123
# -------------------- TEST --------------------
# sun_loss : 0.01163
# ==================== EPOCH :  184 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00088
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  185 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00108
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  186 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00152
# -------------------- TEST --------------------
# sun_loss : 0.01178
# ==================== EPOCH :  187 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00150
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  188 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00167
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  189 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00116
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  190 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00151
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  191 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00149
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  192 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00176
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  193 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00142
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  194 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00109
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  195 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00141
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  196 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00211
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  197 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00133
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  198 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00141
# -------------------- TEST --------------------
# sun_loss : 0.01165
# ==================== EPOCH :  199 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00125
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  200 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00156
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  201 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00149
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  202 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00131
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  203 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00133
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  204 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00143
# -------------------- TEST --------------------
# sun_loss : 0.01181
# ==================== EPOCH :  205 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00143
# -------------------- TEST --------------------
# sun_loss : 0.01165
# ==================== EPOCH :  206 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00146
# -------------------- TEST --------------------
# sun_loss : 0.01182
# ==================== EPOCH :  207 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00150
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  208 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00144
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  209 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00142
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  210 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00144
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  211 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00184
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  212 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00169
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  213 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00153
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  214 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00145
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  215 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00187
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  216 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00137
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  217 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00159
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  218 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00147
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  219 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00111
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  220 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00196
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  221 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00179
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  222 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00120
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  223 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00138
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  224 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00142
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  225 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00116
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  226 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00174
# -------------------- TEST --------------------
# sun_loss : 0.01178
# ==================== EPOCH :  227 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00101
# -------------------- TEST --------------------
# sun_loss : 0.01163
# ==================== EPOCH :  228 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00175
# -------------------- TEST --------------------
# sun_loss : 0.01164
# ==================== EPOCH :  229 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00155
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  230 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00137
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  231 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00142
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  232 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00138
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  233 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00178
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  234 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00185
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  235 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00154
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  236 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00180
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  237 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00174
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  238 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00148
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  239 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00158
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  240 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00149
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  241 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00118
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  242 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00147
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  243 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00116
# -------------------- TEST --------------------
# sun_loss : 0.01178
# ==================== EPOCH :  244 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00163
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  245 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00153
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  246 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00133
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  247 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00154
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  248 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00187
# -------------------- TEST --------------------
# sun_loss : 0.01183
# ==================== EPOCH :  249 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00123
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  250 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00104
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  251 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00164
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  252 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00133
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  253 ====================
# ...
# sun_loss : 0.01174
# ==================== EPOCH :  415 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00162
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  416 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00171
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  417 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00140
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  418 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00114
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  419 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00126
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  420 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00150
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  421 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00157
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  422 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00150
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  423 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00115
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  424 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00148
# -------------------- TEST --------------------
# sun_loss : 0.01178
# ==================== EPOCH :  425 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00110
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  426 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00130
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  427 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00175
# -------------------- TEST --------------------
# sun_loss : 0.01161
# ==================== EPOCH :  428 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00107
# -------------------- TEST --------------------
# sun_loss : 0.01165
# ==================== EPOCH :  429 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00208
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  430 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00170
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  431 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00137
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  432 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00139
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  433 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00187
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  434 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00167
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  435 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00125
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  436 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00129
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  437 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00179
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  438 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00272
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  439 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00132
# -------------------- TEST --------------------
# sun_loss : 0.01172
# ==================== EPOCH :  440 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00125
# -------------------- TEST --------------------
# sun_loss : 0.01178
# ==================== EPOCH :  441 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00121
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  442 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00183
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  443 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00120
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  444 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00151
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  445 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00130
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  446 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00147
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  447 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00124
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  448 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00140
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  449 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00174
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  450 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00112
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  451 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00158
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  452 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00135
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  453 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00121
# -------------------- TEST --------------------
# sun_loss : 0.01164
# ==================== EPOCH :  454 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00156
# -------------------- TEST --------------------
# sun_loss : 0.01167
# ==================== EPOCH :  455 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00140
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  456 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00126
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  457 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00145
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  458 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00175
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  459 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00154
# -------------------- TEST --------------------
# sun_loss : 0.01182
# ==================== EPOCH :  460 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00132
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  461 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00146
# -------------------- TEST --------------------
# sun_loss : 0.01163
# ==================== EPOCH :  462 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00136
# -------------------- TEST --------------------
# sun_loss : 0.01168
# ==================== EPOCH :  463 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00155
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  464 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00179
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  465 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00130
# -------------------- TEST --------------------
# sun_loss : 0.01173
# ==================== EPOCH :  466 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00147
# -------------------- TEST --------------------
# sun_loss : 0.01179
# ==================== EPOCH :  467 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00142
# -------------------- TEST --------------------
# sun_loss : 0.01170
# ==================== EPOCH :  468 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00163
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  469 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00135
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  470 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00114
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  471 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00145
# -------------------- TEST --------------------
# sun_loss : 0.01166
# ==================== EPOCH :  472 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00140
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  473 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00101
# -------------------- TEST --------------------
# sun_loss : 0.01171
# ==================== EPOCH :  474 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00123
# -------------------- TEST --------------------
# sun_loss : 0.01182
# ==================== EPOCH :  475 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00144
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  476 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00161
# -------------------- TEST --------------------
# sun_loss : 0.01178
# ==================== EPOCH :  477 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00192
# -------------------- TEST --------------------
# sun_loss : 0.01169
# ==================== EPOCH :  478 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00146
# -------------------- TEST --------------------
# sun_loss : 0.01176
# ==================== EPOCH :  479 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00143
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  480 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00199
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  481 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00183
# -------------------- TEST --------------------
# sun_loss : 0.01177
# ==================== EPOCH :  482 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00223
# -------------------- TEST --------------------
# sun_loss : 0.01175
# ==================== EPOCH :  483 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00177
# -------------------- TEST --------------------
# sun_loss : 0.01182
# ==================== EPOCH :  484 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.00134
# -------------------- TEST --------------------
# sun_loss : 0.01174
# ==================== EPOCH :  485 ====================
# -------------------- TRAIN --------------------
# sun_loss : 0.
    sum_loss = 0.0
    data_length = len(eval_dataloader)
    suns=[]
    suns_gt=[]
    bins=[]
    angular=[]
    with progressbar.ProgressBar(max_value=data_length) as bar:
        for i, sample in enumerate(eval_dataloader):
            input_img = sample['img'].cuda().float()
            label_dis = sample['dis'].cuda().float()
            sunpos = sample['sp'][0].numpy()

            with torch.no_grad():
                #print("="*20,i,"="*20)
                pred_dis = module(input_img)
                #print("pred_dis  shape : ", pred_dis.shape) # (1, 256)
                #print("pred_dis : ", pred_dis)
                #print("pred_prrs : ", pred_prrs)
                #print(input_img)
                loss = sun_crit(pred_dis, label_dis)
                sum_loss += loss.item()
                
                # calculate all prediction error
                bins.append(np.argmax(pred_dis.cpu().numpy()[0]))
                pred_sunpos = bin2Sphere(np.argmax(pred_dis.cpu().numpy()[0])) # predicted sun position is the bin with highest probability
                #print('pred_sunpos : ', pred_sunpos)
                suns.append(pred_sunpos)
                suns_gt.append(sunpos)
                sunpos_err = getAngle(sunpos, pred_sunpos)
                angular.append(sunpos_err)
                # Sky sun kappa beta turbidity
                sum_err += np.asarray([sunpos_err])
            bar.update(i)
    # print average prediction errors across all testing dataset
    print("="*20,"FINAL ERROR","="*20)
    print('Testing avg loss:', sum_loss/data_length)
    final_err = sum_err/data_length
    print('Average predictions error:')
    print('sun position (angular error):', final_err[0])
    return suns_gt, suns, bins, angular

# %%
def main(args):
    print('loading weights ...')
    # device configuration
    torch.cuda.set_device(0)
    # get network module 
    module = IlluminationModule_SUN_Shadow().cuda()
    #load pre-trained weight
    module.load_state_dict(torch.load(args.pre_trained))

    print('start evaluating ...')
    suns_gt, suns, bins, angular= evaluate(module)
    print('evaluation done!')
    return suns_gt, suns, bins, angular

# %%
if __name__ == '__main__':
    parser = argparse.ArgumentParser()
  
    parser.add_argument('--pre_trained', default='./shadow_17_sun_weights.pth', help='pre-trained weight path')
    
    args = parser.parse_args(args=[])
    
    suns_gt, suns, bins, angular = main(args)
# Out:
# loading weights ...
# start evaluating ...
# <torch.utils.data.dataloader.DataLoader object at 0x7f028307c7b8>
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1932: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn("reduction: 'mean' divides the total loss by both the batch size and the support size."
# 100% (446 of 446) |######################| Elapsed Time: 0:00:02 Time:  0:00:02
# ==================== FINAL ERROR ====================
# Testing avg loss: 0.011598035386991123
# Average predictions error:
# sun position (angular error): 47.26453370279452
# evaluation done!

# %%
print(angular)
# Out:
# [9.434122782198852, 105.78008060836906, 5.531638245335527, 110.11046012631903, 42.90609124061782, 6.254499715017403, 58.91924548865292, 0.44129225614633294, 124.20063066716367, 0.9193430850922502, 71.956652206822, 38.850589084999285, 114.86484858156253, 0.6397194580565669, 38.850589084999285, 77.43115138130109, 51.74136018756699, 11.685387941331578, 33.15607214441112, 75.41089509624786, 105.3749753166864, 110.83076797955293, 116.61392791757426, 64.58601435801779, 4.174986378644119, 61.12545037160217, 12.620146089925553, 12.620146089925553, 41.833798848841894, 2.4913614820074996, 70.1176257175702, 79.98541999399707, 11.798431417598097, 46.738714652261876, 124.27146791590428, 1.768955336561102, 2